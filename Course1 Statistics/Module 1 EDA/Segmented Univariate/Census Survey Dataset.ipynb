# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('EDA_census.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3132 entries, 0 to 3131
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Table Name              3132 non-null   object
#  1   State Code              3132 non-null   int64
#  2   Distt Code              3132 non-null   int64
#  3   Area Name               3132 non-null   object
#  4   Total/Rural/Urban Popu  3132 non-null   object
#  5   Age-group               3132 non-null   object
#  6   Total person            3132 non-null   int64
#  7   Total male              3132 non-null   int64
#  8   Total Female            3132 non-null   int64
#  9   Illiterate person       3132 non-null   int64
#  10  Iliterate male          3132 non-null   int64
#  11  Illiterate female       3132 non-null   int64
#  12  Literate person         3132 non-null   int64
#  13  Literate male           3132 non-null   int64
# ...

# %%
df.shape
df.columns
# Out:
# Index(['Table Name', 'State Code', 'Distt Code', 'Area Name',
#        'Total/Rural/Urban Popu', 'Age-group', 'Total person', 'Total male',
#        'Total Female', 'Illiterate person', 'Iliterate male',
#        'Illiterate female', 'Literate person', 'Literate male',
#        'Literate female'],
#       dtype='object')

# %%
df.isnull().values.any()
# Out:
# False

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[["Age-group","Total Female","Illiterate female"]].corr(),annot=True)
plt.show()

# %%
literacy = (df['Literate person']/df['Total person'])*100

# %%
print(literacy)
# Out:
# 0       63.066084
# 1        0.000000
# 2       72.818658
# 3       84.680522
# 4       89.362038
#           ...
# 3127    66.647695
# 3128    64.878458
# 3129    63.720930
# 3130    57.142857
# 3131    80.851064
# Length: 3132, dtype: float64

# %%
print(df['Age-group'][17])
# Out:
# 30-34

# %%
print(df['Age-group'][15])
# Out:
# 20-24

# %%
print(literacy[15])
# Out:
# 83.235698966783

# %%
df['Literacy Rate'] = literacy

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x=df['Age-group'],y=df['Literacy Rate'])
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x=df['State Code'],y=df['Literacy Rate'])
plt.show()
